# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
path = ("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")
dataset = pd.read_csv(path)
data = dataset.copy()
data.rename(columns={'sepal_length':'SepalLengthCm', 'sepal_width':'SepalWidthCm', 'petal_length':'PetalLengthCm', 'petal_width':'PetalWidthCm', 'species':'Species'}, inplace=True)
print(data)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 0              5.1           3.5            1.4           0.2     setosa
# 1              4.9           3.0            1.4           0.2     setosa
# 2              4.7           3.2            1.3           0.2     setosa
# 3              4.6           3.1            1.5           0.2     setosa
# 4              5.0           3.6            1.4           0.2     setosa
# ..             ...           ...            ...           ...        ...
# 145            6.7           3.0            5.2           2.3  virginica
# 146            6.3           2.5            5.0           1.9  virginica
# 147            6.5           3.0            5.2           2.0  virginica
# 148            6.2           3.4            5.4           2.3  virginica
# 149            5.9           3.0            5.1           1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# Number of columns and rows in iris dataset

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 0              5.1           3.5            1.4           0.2     setosa
# 1              4.9           3.0            1.4           0.2     setosa
# 2              4.7           3.2            1.3           0.2     setosa
# 3              4.6           3.1            1.5           0.2     setosa
# 4              5.0           3.6            1.4           0.2     setosa
# ..             ...           ...            ...           ...        ...
# 145            6.7           3.0            5.2           2.3  virginica
# 146            6.3           2.5            5.0           1.9  virginica
# 147            6.5           3.0            5.2           2.0  virginica
# 148            6.2           3.4            5.4           2.3  virginica
# 149            5.9           3.0            5.1           1.8  virginica
#
# [150 rows x 5 columns]>

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.count()
# Out:
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %% [markdown]
# Grouping

# %%
data.Species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # **Plotting**

# %%
sns.pairplot( data, hue='Species')
plt.show()

# %%
data.min()
# Out:
# SepalLengthCm       4.3
# SepalWidthCm        2.0
# PetalLengthCm       1.0
# PetalWidthCm        0.1
# Species          setosa
# dtype: object

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %% [markdown]
# # **Visualization**

# %%
import seaborn as sns
sns.boxplot(y='sepal_length', data=dataset)
plt.show()

# %%
import seaborn as sns
sns.boxplot(y='sepal_width', data=dataset)
plt.show()

# %%
import seaborn as sns
sns.boxplot(y='petal_length', data=dataset)
plt.show()

# %%
import seaborn as sns
sns.boxplot(y='petal_width', data=dataset)
plt.show()

# %%
sns.boxplot(x='species', y='petal_length', data=dataset)

# %% [markdown]
# **Data PreProcessing or Correlation Matrix**

# %%
plt.subplots(figsize = (8,7))
sns.heatmap(data.corr(), annot=True,fmt="f").set_title("Correlation of attributes among Iris species")
plt.show()

# %% [markdown]
# **From the heatmap, it is observed that the petal length and width are higly correlated**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
x = data.drop(columns=['Species'])
y = data['Species']
x[:5]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %% [markdown]
# # **Splitting dataset into training set and tet set**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state = 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
svm = SVC()
nb = GaussianNB()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()

# %% [markdown]
# # **Training and Evaluating Models**

# %%
models = [lr,knn,svm,nb,dt,rf]
scores = []
for model in models:
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  scores.append(accuracy_score(y_test, y_pred))
  print("Accuracy of "+ type(model).__name__+" is", accuracy_score(y_test, y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9777777777777777
# Accuracy of KNeighborsClassifier is 0.9777777777777777
# Accuracy of SVC is 0.9777777777777777
# Accuracy of GaussianNB is 0.9333333333333333
# Accuracy of DecisionTreeClassifier is 0.9555555555555556
# Accuracy of RandomForestClassifier is 0.9555555555555556

# %%
results = pd.DataFrame({
    'models' : ['Logistic Regression', 'K-Nearest Neighbors', 'Support Vector Machine', 'Naive Bayes', 'Decision Tree', 'Random Forest'], 'Accuracy':scores})
results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                    models  Accuracy
# 0     Logistic Regression  0.977778
# 1     K-Nearest Neighbors  0.977778
# 2  Support Vector Machine  0.977778
# 4           Decision Tree  0.955556
# 5           Random Forest  0.955556
# 3             Naive Bayes  0.933333
